# %% [markdown]
# this notebook computes the measurements for the bulk study. The notebook is self contain, it only requieres some standar python libraries.
#
# Idea and implementation by Diego Guarin

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline

# %%
def get_info_from_txt(file):
    #function to read the landmark, iris and bounding box location from txt files
    shape=np.zeros((68,2),dtype=int)
    left_pupil = np.zeros((1,3),dtype=int)
    right_pupil = np.zeros((1,3),dtype=int)
    bounding_box = np.zeros((1,4),dtype=int)
    
    cont_landmarks = 0
    get_landmarks = 0
    
    get_leftpupil = 0
    cont_leftpupil = 0
    
    get_rightpupil = 0
    cont_rightpupil = 0
    
    get_boundingbox = 0
    cont_boundingbox = 0 
    with open(file, 'r') as file:
        for i,line in enumerate(file):    
            if i == 4:    
                get_landmarks=1
            if i == 72:
                get_landmarks=0
                
            if get_landmarks == 1:
                temp=(line[:]).split(',')
                shape[cont_landmarks,0]=int(temp[0])
                shape[cont_landmarks,1]=int(temp[1])
                cont_landmarks += 1
                
            if i == 74:
                get_leftpupil = 1
            if i == 77:
                get_leftpupil = 0
                
            if get_leftpupil == 1:
                left_pupil[0,cont_leftpupil]=int(line[:])
                cont_leftpupil += 1
    
            if i == 79:
                get_rightpupil = 1
            if i == 82:
                get_rightpupil = 0
                
            if get_rightpupil == 1:            
                right_pupil[0,cont_rightpupil]=int(line[:])
                cont_rightpupil += 1 
                
            if i == 84:
                get_boundingbox = 1
            if i == 88:
                get_boundingbox = 0
                 
            if get_boundingbox == 1 :
                bounding_box[0,cont_boundingbox] = int(line[:])
                cont_boundingbox +=1
     
    lefteye=[left_pupil[0,0],left_pupil[0,1],left_pupil[0,2]]
    righteye=[right_pupil[0,0],right_pupil[0,1],right_pupil[0,2]]
    
    if cont_boundingbox > 0 :
        boundingbox = [bounding_box[0,0],bounding_box[0,1],bounding_box[0,2],bounding_box[0,3]]    
    else:
        boundingbox = [0,0,0,0]
    
    if lefteye[2] < 0 and righteye[2] >0:
        #left eye is closed, use right iris diameter and locate iris in center of eye
        lefteye[2] = righteye[2]           
        x_eye = shape[42:47,0]
        y_eye = shape[42:47,1]
        lefteye[0] = int(np.round(np.mean(x_eye),0))
        lefteye[1] = int(np.round(np.mean(y_eye),0))
        #message = 'Left Eye Closed'
         
    if righteye[2] < 0 and lefteye[2] >0:
        #Right eye is closed, use left iris diameter and locate iris in center of eye
        righteye[2] = lefteye[2]
        x_eye = shape[36:41,0]
        y_eye = shape[36:41,1]
        righteye[0] = int(np.round(np.mean(x_eye),0))
        righteye[1] = int(np.round(np.mean(y_eye),0))
        #message = 'Right Eye Closed'
            
    if righteye[2] < 0 and lefteye[2] <0:
        #both eyes are closed, use 1/4 of eye lenght as radius
        #and the center of mass of the eye as the center
        
        #for left eye 
        x_eye = shape[42:47,0]
        y_eye = shape[42:47,1]
        lefteye[0] = int(np.round(np.mean(x_eye),0))
        lefteye[1] = int(np.round(np.mean(y_eye),0))
        lefteye[2] = int(np.round((shape[45,0]-lefteye[0])/2))
        
        #for right eye 
        x_eye = shape[36:41,0]
        y_eye = shape[36:41,1]
        righteye[0] = int(np.round(np.mean(x_eye),0))
        righteye[1] = int(np.round(np.mean(y_eye),0))
        righteye[2] = int(np.round((shape[39,0]-righteye[0])/2))
        #message = 'Both Eyes Closed'
           
    return shape, lefteye, righteye, boundingbox

def estimate_lines(circle_left, circle_right):
    #function to estimate the line that connects the center of the eyes and a 
    #new, perpendicular line in the middle
    
    x_1=circle_right[0]
    y_1=circle_right[1]
    
    x_2=circle_left[0]
    y_2=circle_left[1]
    
    #find the point in the middle of the line
    x_m=((x_2-x_1)/2)+x_1
    m=(y_2-y_1)/(x_2-x_1)   
    y_m=(y_1+m*(x_m-x_1))
    
    x_m=int(round(x_m,0))
    y_m=int(round(y_m,0))
    angle=np.arctan(m)
    
    
    points=[x_m,y_m]
    
    return angle, points

# %%
def find_bulk_metrics(file, conversion_scale = 11.77, valid_image = True):



    shape, left_eye, right_eye, bounding_box = get_info_from_txt(file)
    angle, center = estimate_lines(left_eye, right_eye)

    scale = conversion_scale/(2*((left_eye[2]+right_eye[2])/2))


    rot_angle = angle+np.pi/2
    rot_matrix=np.array([[np.cos(rot_angle), np.sin(rot_angle)],
                      [-np.sin(rot_angle), np.cos(rot_angle)]])
    rot_matrix_inv=np.array([[np.cos(rot_angle), -np.sin(rot_angle)],
                  [np.sin(rot_angle), np.cos(rot_angle)]])



    x=shape[:,0]
    y=shape[:,1]
    rot_x,rot_y=rot_matrix.dot([x-center[0],y-center[1]])

    #left side of the face

    x=shape[12:17,0]
    y=shape[12:17,1]
    rot_x,rot_y=rot_matrix.dot([x-center[0],y-center[1]])


    spline = UnivariateSpline(rot_x[::-1],rot_y[::-1], s=1) 
    new_x_left = np.linspace(rot_x.min(), rot_x.max(),100)
    new_y_left = spline(new_x_left)
    idx = np.argmin(new_y_left)
    max_bulk_y_left = new_y_left[idx]
    max_bulk_x_left = new_x_left[idx]
    dist_left = abs(scale*max_bulk_y_left)

    #Right side of the face

    x=shape[0:5,0]
    y=shape[0:5,1]
    rot_x,rot_y=rot_matrix.dot([x-center[0],y-center[1]])


    spline = UnivariateSpline(rot_x,rot_y, s=1) 
    new_x_right = np.linspace(rot_x.min(), rot_x.max(),100)
    new_y_right = spline(new_x_right)
    idx = np.argmax(new_y_right)
    max_bulk_y_right = new_y_right[idx]
    max_bulk_x_right = new_x_right[idx]
    dist_right = abs(scale*max_bulk_y_right)


    if valid_image: 
        straight_new_x_left, straight_new_y_left = rot_matrix_inv.dot([new_x_left, new_y_left])
        straight_new_x_left, straight_new_y_left = straight_new_x_left+center[0], straight_new_y_left+center[1]

        straight_new_x_right, straight_new_y_right = rot_matrix_inv.dot([new_x_right, new_y_right])
        straight_new_x_right, straight_new_y_right = straight_new_x_right+center[0], straight_new_y_right+center[1]

        point_border_x_left, point_border_y_left = rot_matrix_inv.dot([max_bulk_x_left, max_bulk_y_left])
        point_border_x_left, point_border_y_left = point_border_x_left + center[0], point_border_y_left + center[1]
        point_center_x_left, point_center_y_left = rot_matrix_inv.dot([max_bulk_x_left,0])
        point_center_x_left, point_center_y_left = point_center_x_left + center[0], point_center_y_left + center[1]

        point_border_x_right, point_border_y_right = rot_matrix_inv.dot([max_bulk_x_right, max_bulk_y_right])
        point_border_x_right, point_border_y_right = point_border_x_right + center[0], point_border_y_right + center[1]
        point_center_x_right, point_center_y_right = rot_matrix_inv.dot([max_bulk_x_right,0])
        point_center_x_right, point_center_y_right = point_center_x_right + center[0], point_center_y_right + center[1]


        center_line_x, center_line_y = rot_matrix_inv.dot([300,0])
        center_line_x, center_line_y = center_line_x + center[0], center_line_y+center[1]

        fig  = plt.figure(figsize=(9,10))
        ax = fig.add_subplot(1, 1, 1)
        plt.scatter(shape[:,0], -shape[:,1])
        plt.plot(center[0],-center[1],'r',marker='o',markersize=10)
        plt.plot(np.array([center[0],center_line_x]), -np.array([center[1],center_line_y]), linewidth=1, color='tab:red')
        plt.plot(np.array([left_eye[0], right_eye[0]]), -np.array([left_eye[1], right_eye[1]]), linewidth=1, color='tab:red')
        plt.plot(straight_new_x_left, -straight_new_y_left, color='k')
        plt.plot(straight_new_x_right, -straight_new_y_right, color = 'k')
        plt.plot(np.array([point_border_x_left]), -np.array([point_border_y_left]), marker='o', markersize=5, color = 'tab:green')
        plt.plot(np.array([point_center_x_left, point_border_x_left]), -np.array([point_center_y_left, point_border_y_left]), color = 'tab:green')
        plt.text((point_border_x_left-point_center_x_left)/2 + point_center_x_left, -(point_center_y_left-20),str(np.round(dist_left,2)) + ' cm', fontsize=12)
        plt.plot(np.array([point_border_x_right]), -np.array([point_border_y_right]), marker='o', markersize=5, color = 'tab:orange')
        plt.plot(np.array([point_center_x_right, point_border_x_right]), -np.array([point_center_y_right, point_border_y_right]), color = 'tab:orange')
        plt.text((point_center_x_right-point_border_x_right)/2 + point_border_x_right, -(point_center_y_right-20),str(np.round(dist_right,2)) + ' cm', fontsize=12)

        plt.plot(left_eye[0], -left_eye[1], marker='o', markersize=left_eye[2], markerfacecolor='none', markeredgecolor= 'tab:red')
        plt.plot(right_eye[0], -right_eye[1], marker='o', markersize=right_eye[2], markerfacecolor='none', markeredgecolor= 'tab:red')

        frame1 = plt.gca()
        frame1.axes.xaxis.set_ticklabels([])
        frame1.axes.yaxis.set_ticklabels([])
        plt.savefig(file[:-3]+'png')
        plt.close()
        
    return dist_left, dist_right

# %%
folder = r'C:\Users\guarind\Documents\GitHub\Bulk_meatrics\data\text_files'
folder = r'C:\Users\guarind\Documents\GitHub\Bulk_meatrics\data\text_files_update'
files = [f for f in os.listdir(folder) if f.endswith('.txt')]
files.sort()

data = pd.DataFrame(columns=['id', 'left (cm)', 'right (cm)'])
cl0=[]
cl1=[]
cl2=[]
for file in files:
    left, right = find_bulk_metrics(os.path.join(folder, file))
    cl0.append(file[:-4])
    cl1.append(left)
    cl2.append(right)
    
data['id'] = cl0
data['left (cm)'] = cl1
data['right (cm)'] = cl2
    
data.to_csv(os.path.join(folder, 'results.csv'))

# %%
folder = r'C:\Users\guarind\Documents\GitHub\Bulk_meatrics\data\text_files_2010_2011'
#folder = r'C:\Users\guarind\Documents\GitHub\Bulk_meatrics\data\text_files_update'
files_two = [f for f in os.listdir(folder) if f.endswith('.txt')]
files_two.sort()

data_two = pd.DataFrame(columns=['id', 'left (cm)', 'right (cm)'])
cl0=[]
cl1=[]
cl2=[]
for file in files_two:
    if file[:-4] in data['id'].tolist():
        pass
    else:
        left, right = find_bulk_metrics(os.path.join(folder, file))
        cl0.append(file[:-4])
        cl1.append(left)
        cl2.append(right)
    
data_two['id'] = cl0
data_two['left (cm)'] = cl1
data_two['right (cm)'] = cl2
    
data_two.to_csv(os.path.join(folder, 'results_text_files_2010_2011.csv'))

# %%
files.sort()
files
# Out:
# ['1000306_post_repose.txt',
#  '1000306_post_smile.txt',
#  '1000306_pre_repose.txt',
#  '1000306_pre_smile.txt',
#  '1009905_post_repose.txt',
#  '1009905_post_smile.txt',
#  '1009905_pre_repose.txt',
#  '1009905_pre_smile.txt',
#  '1011068_post_repose.txt',
#  '1011068_post_smile.txt',
#  '1011068_pre_repose.txt',
#  '1011068_pre_smile.txt',
#  '1011576_post_repose.txt',
#  '1011576_post_smile.txt',
#  '1011576_pre_repose.txt',
#  '1011576_pre_smile.txt',
#  '1032027_post_repose.txt',
#  '1032027_post_smile.txt',
#  '1032027_pre_repose.txt',
#  '1032027_pre_smile.txt',
#  '1038325_post_repose.txt',
#  '1038325_post_smile.txt',
#  '1038325_pre_repose.txt',
#  '1038325_pre_smile.txt',
#  '7071738_post_repose.txt',
#  '7071738_post_smile.txt',
#  '7071738_pre_repose.txt',
#  '7071738_pre_smile.txt',
#  '7094090_post_repose.txt',
#  '7094090_post_smile.txt',
#  '7094090_pre_repose.txt',
#  '7094090_pre_smile.txt',
#  '7097101_post_repose.txt',
#  '7097101_post_smile.txt',
#  '7097101_pre_repose.txt',
#  '7097101_pre_smile.txt',
#  '7166808_post_repose.txt',
#  '7166808_post_smile.txt',
#  '7166808_pre_repose.txt',
#  '7166808_pre_smile.txt',
#  '7296772_post_repose.txt',
#  '7296772_post_smile.txt',
#  '7296772_pre_repose.txt',
#  '7296772_pre_smile.txt',
#  '7338307_post_repose.txt',
#  '7338307_post_smile.txt',
#  '7338307_pre_repose.txt',
#  '7338307_pre_smile.txt',
#  '7373065_post_repose.txt',
#  '7373065_post_smile.txt',
#  '7373065_pre_repose.txt',
#  '7373065_pre_smile.txt',
#  '7377344_post_repose.txt',
#  '7377344_post_smile.txt',
#  '7377344_pre_repose.txt',
#  '7377344_pre_smile.txt',
#  '7382178_post_repose.txt',
#  '7382178_post_smile.txt',
#  '7382178_pre_repose.txt',
#  '7382178_pre_smile.txt',
#  '7391235_post_repose.txt',
#  '7391235_post_smile.txt',
#  '7391235_pre_repose.txt',
#  '7391235_pre_smile.txt',
#  '7396023_post_repose.txt',
#  '7396023_post_smile.txt',
#  '7396023_pre_repose.txt',
#  '7396023_pre_smile.txt',
#  '7410854_post_repose.txt',
#  '7410854_post_smile.txt',
#  '7410854_pre_repose.txt',
#  '7410854_pre_smile.txt',
#  '7436810_post_repose.txt',
#  '7436810_post_smile.txt',
#  '7436810_pre_repose.txt',
#  '7436810_pre_smile.txt',
#  '7446956_post_repose.txt',
#  '7446956_post_smile.txt',
#  '7446956_pre_repose.txt',
#  '7446956_pre_smile.txt',
#  '7458342_post_repose.txt',
#  '7458342_post_smile.txt',
#  '7458342_pre_repose.txt',
#  '7458342_pre_smile.txt',
#  '7462309_post_repose.txt',
#  '7462309_post_smile.txt',
#  '7462309_pre_repose.txt',
#  '7462309_pre_smile.txt',
#  '7487140_post_repose.txt',
#  '7487140_post_smile.txt',
#  '7487140_pre_repose.txt',
#  '7487140_pre_smile.txt',
#  '7487649_post_repose.txt',
#  '7487649_post_smile.txt',
#  '7487649_pre_repose.txt',
#  '7487649_pre_smile.txt',
#  '7503861_post_repose.txt',
#  '7503861_post_smile.txt',
#  '7503861_pre_repose.txt',
#  '7503861_pre_smile.txt',
#  '7507401_post_repose.txt',
#  '7507401_post_smile.txt',
#  '7507401_pre_repose.txt',
#  '7507401_pre_smile.txt',
#  '7515896_post_repose.txt',
#  '7515896_post_smile.txt',
#  '7515896_pre_repose.txt',
#  '7515896_pre_smile.txt',
#  '7516470_post_repose.txt',
#  '7516470_post_smile.txt',
#  '7516470_pre_repose.txt',
#  '7516470_pre_smile.txt',
#  '7516874_post_repose.txt',
#  '7516874_post_smile.txt',
#  '7516874_pre_repose.txt',
#  '7516874_pre_smile.txt',
#  '7601472_post_repose.txt',
#  '7601472_post_smile.txt',
#  '7601472_pre_repose.txt',
#  '7601472_pre_smile.txt',
#  '7605759_post_repose.txt',
#  '7605759_post_smile.txt',
#  '7605759_pre_repose.txt',
#  '7605759_pre_smile.txt',
#  '7605949_post_repose.txt',
#  '7605949_post_smile.txt',
#  '7605949_pre_repose.txt',
#  '7605949_pre_smile.txt',
#  '7613493_post_repose.txt',
#  '7613493_post_smile.txt',
#  '7613493_pre_repose.txt',
#  '7613493_pre_smile.txt',
#  '7621323_post_repose.txt',
#  '7621323_post_smile.txt',
#  '7621323_pre_repose.txt',
#  '7621323_pre_smile.txt',
#  '7625560_post_repose.txt',
#  '7625560_post_smile.txt',
#  '7625560_pre_repose.txt',
#  '7625560_pre_smile.txt',
#  '7641470_post_repose.txt',
#  '7641470_post_smile.txt',
#  '7641470_pre_repose.txt',
#  '7641470_pre_smile.txt',
#  '7643505_post_repose.txt',
#  '7643505_post_smile.txt',
#  '7643505_pre_repose.txt',
#  '7643505_pre_smile.txt',
#  '7643783_post_repose.txt',
#  '7643783_post_smile.txt',
#  '7643783_pre_repose.txt',
#  '7643783_pre_smile.txt',
#  '7645082_post_repose.txt',
#  '7645082_post_smile.txt',
#  '7645082_pre_repose.txt',
#  '7645082_pre_smile.txt',
#  '7671616_post_repose.txt',
#  '7671616_post_smile.txt',
#  '7671616_pre_repose.txt',
#  '7671616_pre_smile.txt',
#  '7673139_post_repose.txt',
#  '7673139_post_smile.txt',
#  '7673139_pre_repose.txt',
#  '7673139_pre_smile.txt',
#  '7679289_post_repose.txt',
#  '7679289_post_smile.txt',
#  '7679289_pre_repose.txt',
#  '7679289_pre_smile.txt',
#  '7682396_post_repose.txt',
#  '7682396_post_smile.txt',
#  '7682396_pre_repose.txt',
#  '7682396_pre_smile.txt',
#  '7688083_post_repose.txt',
#  '7688083_post_smile.txt',
#  '7688083_pre_repose.txt',
#  '7688083_pre_smile.txt',
#  '7694716_post_repose.txt',
#  '7694716_post_smile.txt',
#  '7694716_pre_repose.txt',
#  '7694716_pre_smile.txt',
#  '7705245_post_repose.txt',
#  '7705245_post_smile.txt',
#  '7705245_pre_repose.txt',
#  '7705245_pre_smile.txt',
#  '7707944_post_repose.txt',
#  '7707944_post_smile.txt',
#  '7707944_pre_repose.txt',
#  '7707944_pre_smile.txt',
#  '7709563_post_repose.txt',
#  '7709563_post_smile.txt',
#  '7709563_pre_repose.txt',
#  '7709563_pre_smile.txt',
#  '7710681_post_repose.txt',
#  '7710681_post_smile.txt',
#  '7710681_pre_repose.txt',
#  '7710681_pre_smile.txt',
#  '7714355_post_repose.txt',
#  '7714355_post_smile.txt',
#  '7714355_pre_repose.txt',
#  '7714355_pre_smile.txt',
#  '7716979_post_repose.txt',
#  '7716979_post_smile.txt',
#  '7716979_pre_repose.txt',
#  '7716979_pre_smile.txt',
#  '7717011_post_repose.txt',
#  '7717011_post_smile.txt',
#  '7717011_pre_repose.txt',
#  '7717011_pre_smile.txt',
#  '7725523_post_repose.txt',
#  '7725523_post_smile.txt',
#  '7725523_pre_repose.txt',
#  '7725523_pre_smile.txt',
#  '7725803_post_repose.txt',
#  '7725803_post_smile.txt',
#  '7725803_pre_repose.txt',
#  '7725803_pre_smile.txt',
#  '7733786_post_repose.txt',
#  '7733786_post_smile.txt',
#  '7733786_pre_repose.txt',
#  '7733786_pre_smile.txt',
#  '7733839_post_repose.txt',
#  '7733839_post_smile.txt',
#  '7733839_pre_repose.txt',
#  '7733839_pre_smile.txt',
#  '7739213_post_repose.txt',
#  '7739213_post_smile.txt',
#  '7739213_pre_repose.txt',
#  '7739213_pre_smile.txt',
#  '7741833_post_repose.txt',
#  '7741833_post_smile.txt',
#  '7741833_pre_repose.txt',
#  '7741833_pre_smile.txt',
#  '7741844_post_repose.txt',
#  '7741844_post_smile.txt',
#  '7741844_pre_repose.txt',
#  '7741844_pre_smile.txt',
#  '7746859_post_repose.txt',
#  '7746859_post_smile.txt',
#  '7746859_pre_repose.txt',
#  '7746859_pre_smile.txt',
#  '7747698_post_repose.txt',
#  '7747698_post_smile.txt',
#  '7747698_pre_repose.txt',
#  '7747698_pre_smile.txt',
#  '7750328_post_repose.txt',
#  '7750328_post_smile.txt',
#  '7750328_pre_repose.txt',
#  '7750328_pre_smile.txt',
#  '7777191_post_repose.txt',
#  '7777191_post_smile.txt',
#  '7777191_pre_repose.txt',
#  '7777191_pre_smile.txt',
#  '7778681_post_repose.txt',
#  '7778681_post_smile.txt',
#  '7778681_pre_repose.txt',
#  '7778681_pre_smile.txt',
#  '7785231_post_repose.txt',
#  '7785231_post_smile.txt',
#  '7785231_pre_repose.txt',
#  '7785231_pre_smile.txt',
#  '7785464_post_repose.txt',
#  '7785464_post_smile.txt',
#  '7785464_pre_repose.txt',
#  '7785464_pre_smile.txt',
#  '7808286_post_repose.txt',
#  '7808286_post_smile.txt',
#  '7808286_pre_repose.txt',
#  '7808286_pre_smile.txt',
#  '7810512_post_repose.txt',
#  '7810512_post_smile.txt',
#  '7810512_pre_repose.txt',
#  '7810512_pre_smile.txt',
#  '7828121_post_repose.txt',
#  '7828121_post_smile.txt',
#  '7828121_pre_repose.txt',
#  '7828121_pre_smile.txt',
#  '7828559_post_repose.txt',
#  '7828559_post_smile.txt',
#  '7828559_pre_repose.txt',
#  '7828559_pre_smile.txt',
#  '7836543_post_repose.txt',
#  '7836543_post_smile.txt',
#  '7836543_pre_repose.txt',
#  '7836543_pre_smile.txt',
#  '7836683_post_repose.txt',
#  '7836683_post_smile.txt',
#  '7836683_pre_repose.txt',
#  '7836683_pre_smile.txt',
#  '7841222_post_repose.txt',
#  '7841222_post_smile.txt',
#  '7841222_pre_repose.txt',
#  '7841222_pre_smile.txt',
#  '7842995_post_repose.txt',
#  '7842995_post_smile.txt',
#  '7842995_pre_repose.txt',
#  '7842995_pre_smile.txt',
#  '7849417_post_repose.txt',
#  '7849417_post_smile.txt',
#  '7849417_pre_repose.txt',
#  '7849417_pre_smile.txt',
#  '7853223_post_repose.txt',
#  '7853223_post_smile.txt',
#  '7853223_pre_repose.txt',
#  '7853223_pre_smile.txt',
#  '7859692_post_repose.txt',
#  '7859692_post_smile.txt',
#  '7859692_pre_repose.txt',
#  '7859692_pre_smile.txt',
#  '7864758_post_repose.txt',
#  '7864758_post_smile.txt',
#  '7864758_pre_repose.txt',
#  '7864758_pre_smile.txt',
#  '7866439_post_repose.txt',
#  '7866439_post_smile.txt',
#  '7866439_pre_repose.txt',
#  '7866439_pre_smile.txt',
#  '7888400_post_repose.txt',
#  '7888400_post_smile.txt',
#  '7888400_pre_repose.txt',
#  '7888400_pre_smile.txt',
#  '7894716_post_repose.txt',
#  '7894716_post_smile.txt',
#  '7894716_pre_repose.txt',
#  '7894716_pre_smile.txt',
#  '7901929_post_repose.txt',
#  '7901929_post_smile.txt',
#  '7901929_pre_repose.txt',
#  '7901929_pre_smile.txt',
#  '7903207_post_repose.txt',
#  '7903207_post_smile.txt',
#  '7903207_pre_repose.txt',
#  '7903207_pre_smile.txt',
#  '7905505_post_repose.txt',
#  '7905505_post_smile.txt',
#  '7905505_pre_repose.txt',
#  '7905505_pre_smile.txt',
#  '7912176_post_repose.txt',
#  '7912176_post_smile.txt',
#  '7912176_pre_repose.txt',
#  '7912176_pre_smile.txt',
#  '7915896_post_repose.txt',
#  '7915896_post_smile.txt',
#  '7915896_pre_repose.txt',
#  '7915896_pre_smile.txt',
#  '7919056_post_repose.txt',
#  '7919056_post_smile.txt',
#  '7919056_pre_repose.txt',
#  '7919056_pre_smile.txt',
#  '7921879_post_repose.txt',
#  '7921879_post_smile.txt',
#  '7921879_pre_repose.txt',
#  '7921879_pre_smile.txt',
#  '7922029_post_repose.txt',
#  '7922029_post_smile.txt',
#  '7922029_pre_repose.txt',
#  '7922029_pre_smile.txt',
#  '7923305_post_repose.txt',
#  '7923305_post_smile.txt',
#  '7923305_pre_repose.txt',
#  '7923305_pre_smile.txt',
#  '7943807_post_repose.txt',
#  '7943807_post_smile.txt',
#  '7943807_pre_repose.txt',
#  '7943807_pre_smile.txt',
#  '7947333_post_repose.txt',
#  '7947333_post_smile.txt',
#  '7947333_pre_repose.txt',
#  '7947333_pre_smile.txt',
#  '7989297_post_repose.txt',
#  '7989297_post_smile.txt',
#  '7989297_pre_repose.txt',
#  '7989297_pre_smile.txt',
#  '7991304_post_repose.txt',
#  '7991304_post_smile.txt',
#  '7991304_pre_repose.txt',
#  '7991304_pre_smile.txt',
#  '7994145_post_repose.txt',
#  '7994145_post_smile.txt',
#  '7994145_pre_repose.txt',
#  '7994145_pre_smile.txt',
#  '7995187_post_repose.txt',
#  '7995187_post_smile.txt',
#  '7995187_pre_repose.txt',
#  '7995187_pre_smile.txt',
#  '7995323_post_repose.txt',
#  '7995323_post_smile.txt',
#  '7995323_pre_repose.txt',
#  '7995323_pre_smile.txt',
#  '7997005_post_repose.txt',
#  '7997005_post_smile.txt',
#  '7997005_pre_repose.txt',
#  '7997005_pre_smile.txt',
#  '8005065_post_repose.txt',
#  '8005065_post_smile.txt',
#  '8005065_pre_repose.txt',
#  '8005065_pre_smile.txt',
#  '8006610_post_repose.txt',
#  '8006610_post_smile.txt',
#  '8006610_pre_repose.txt',
#  '8006610_pre_smile.txt',
#  '8010104_post_repose.txt',
#  '8010104_post_smile.txt',
#  '8010104_pre_repose.txt',
#  '8010104_pre_smile.txt',
#  '8017784_post_repose.txt',
#  '8017784_post_smile.txt',
#  '8017784_pre_repose.txt',
#  '8017784_pre_smile.txt',
#  '8018914_post_repose.txt',
#  '8018914_post_smile.txt',
#  '8018914_pre_repose.txt',
#  '8018914_pre_smile.txt',
#  '8025731_post_repose.txt',
#  '8025731_post_smile.txt',
#  '8025731_pre_repose.txt',
#  '8025731_pre_smile.txt',
#  '8032561_post_repose.txt',
#  '8032561_post_smile.txt',
#  '8032561_pre_repose.txt',
#  '8032561_pre_smile.txt',
#  '8032758_post_repose.txt',
#  '8032758_post_smile.txt',
#  '8032758_pre_repose.txt',
#  '8032758_pre_smile.txt',
#  '8043719_post_repose.txt',
#  '8043719_post_smile.txt',
#  '8043719_pre_repose.txt',
#  '8043719_pre_smile.txt',
#  '8060750_post_repose.txt',
#  '8060750_post_smile.txt',
#  '8060750_pre_repose.txt',
#  '8060750_pre_smile.txt',
#  '8061200_post_repose.txt',
#  '8061200_post_smile.txt',
#  '8061200_pre_repose.txt',
#  '8061200_pre_smile.txt',
#  '8063021_post_repose.txt',
#  '8063021_post_smile.txt',
#  '8063021_pre_repose.txt',
#  '8063021_pre_smile.txt',
#  '8066781_post_repose.txt',
#  '8066781_post_smile.txt',
#  '8066781_pre_repose.txt',
#  '8066781_pre_smile.txt',
#  '8066914_post_repose.txt',
#  '8066914_post_smile.txt',
#  '8066914_pre_repose.txt',
#  '8066914_pre_smile.txt',
#  '8069924_post_repose.txt',
#  '8069924_post_smile.txt',
#  '8069924_pre_repose.txt',
#  '8069924_pre_smile.txt',
#  '9141799_post_repose.txt',
#  '9141799_post_smile.txt',
#  '9141799_pre_repose.txt',
#  '9141799_pre_smile.txt',
#  '9181193_post_repose.txt',
#  '9181193_post_smile.txt',
#  '9181193_pre_repose.txt',
#  '9181193_pre_smile.txt',
#  '9229820_post_repose.txt',
#  '9229820_post_smile.txt',
#  '9229820_pre_repose.txt',
#  '9229820_pre_smile.txt',
#  '9371600_post_repose.txt',
#  '9371600_post_smile.txt',
#  '9371600_pre_repose.txt',
#  '9371600_pre_smile.txt',
#  '9402050_post_repose.txt',
#  '9402050_post_smile.txt',
#  '9402050_pre_repose.txt',
#  '9402050_pre_smile.txt',
#  '9413001_post_repose.txt',
#  '9413001_post_smile.txt',
#  '9413001_pre_repose.txt',
#  '9413001_pre_smile.txt',
#  '9458778_post_repose.txt',
#  '9458778_post_smile.txt',
#  '9458778_pre_repose.txt',
#  '9458778_pre_smile.txt',
#  '9560262_post_repose.txt',
#  '9560262_post_smile.txt',
#  '9560262_pre_repose.txt',
#  '9560262_pre_smile.txt',
#  '9605977_post_repose.txt',
#  '9605977_post_smile.txt',
#  '9605977_pre_repose.txt',
#  '9605977_pre_smile.txt',
#  '9631679_post_repose.txt',
#  '9631679_post_smile.txt',
#  '9631679_pre_repose.txt',
#  '9631679_pre_smile.txt',
#  '9949199_post_repose.txt',
#  '9949199_post_smile.txt',
#  '9949199_pre_repose.txt',
#  '9949199_pre_smile.txt',
#  '9950030_post_repose.txt',
#  '9950030_post_smile.txt',
#  '9950030_pre_repose.txt',
#  '9950030_pre_smile.txt',
#  '9952183_post_repose.txt',
#  '9952183_post_smile.txt',
#  '9952183_pre_repose.txt',
#  '9952183_pre_smile.txt',
#  '9957413_post_repose.txt',
#  '9957413_post_smile.txt',
#  '9957413_pre_repose.txt',
#  '9957413_pre_smile.txt',
#  '9964409_post_repose.txt',
#  '9964409_post_smile.txt',
#  '9964409_pre_repose.txt',
#  '9964409_pre_smile.txt',
#  '9969385_post_repose.txt',
#  '9969385_post_smile.txt',
#  '9969385_pre_repose.txt',
#  '9969385_pre_smile.txt']
